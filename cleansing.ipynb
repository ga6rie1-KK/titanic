# %% [markdown]
# # インポート

# %%
import pandas as pd
from math import log, exp

# %% [markdown]
# # 一回目

# %% [markdown]
# ## ダウンロード

# %%
df_train = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Ageをバンドリングする
# 10歳ごとにバンドリングする
# - 変数名：Age_by10
# - [n, n+10) = n

# %%
df_train["Age_by10"] = df_train["Age"]//10*10

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_by10
# 0      0         A/5 21171   7.2500   NaN        S      20.0
# 1      0          PC 17599  71.2833   C85        C      30.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      20.0
# 3      0            113803  53.1000  C123        S      30.0
# 4      0            373450   8.0500   NaN        S      30.0

# %%
df_test["Age_by10"] = df_test["Age"]//10*10

# %% [markdown]
# ## Fareをバンドリングする
# x → log(log(x+1)+1)にして, 0.2ごとにバンドリング
# - 変数名：Fare_banded
# - [log(log(x+1)+1), log(log(x+1)+1)+0.2) = x//1

# %%
tmp = df_train["Fare"].map(lambda x: log(log(x+1)+1))
df_train["Fare_banded"] = (tmp//0.2*0.2).map(lambda x: exp(exp(x)-1)-1)//1

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_by10  Fare_banded
# 0      0         A/5 21171   7.2500   NaN        S      20.0          4.0
# 1      0          PC 17599  71.2833   C85        C      30.0         51.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      20.0          4.0
# 3      0            113803  53.1000  C123        S      30.0         51.0
# 4      0            373450   8.0500   NaN        S      30.0          4.0

# %%
tmp = df_test["Fare"].map(lambda x: log(log(x+1)+1))
df_test["Fare_banded"] = (tmp//0.2*0.2).map(lambda x: exp(exp(x)-1)-1)//1

# %% [markdown]
# ## Embarkedを順序付きカテゴリカルデータに変換する
# S → 1, C → 2, Q → 3
# - 変数名：Embarked_int

# %%
def f(s):
    if s == "S":
        return 1
    elif s == "C":
        return 2
    elif s == "Q":
        return 3
    else:
        return s

# %%
df_train["Embarked_int"] = df_train["Embarked"].map(f)

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_by10  Fare_banded  \
# 0      0         A/5 21171   7.2500   NaN        S      20.0          4.0
# 1      0          PC 17599  71.2833   C85        C      30.0         51.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      20.0          4.0
# 3      0            113803  53.1000  C123        S      30.0         51.0
# 4      0            373450   8.0500   NaN        S      30.0          4.0
#
#    Embarked_int
# 0           1.0
# 1           2.0
# 2           1.0
# 3           1.0
# 4           1.0

# %%
df_test["Embarked_int"] = df_test["Embarked"].map(f)

# %% [markdown]
# ## 保存する

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (891, 15)
# (418, 14)

# %%
df_train.to_csv("data/cleansed_train.csv", index=False)
df_test.to_csv("data/cleansed_test.csv", index=False)
